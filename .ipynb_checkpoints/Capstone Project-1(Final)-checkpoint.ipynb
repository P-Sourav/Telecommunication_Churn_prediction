# %% [markdown]
# # Telecommunication Churn Prediction Model
# ## Importing all the important libraries

# %%
import pandas as pd 
import numpy as np      
import seaborn as sns                 
import matplotlib.pyplot as plt       
# %matplotlib inline 
#pip install plotly
import plotly.express as px
plt.rcParams.update(plt.rcParamsDefault)

import warnings  
warnings.filterwarnings("ignore")

# %% [markdown]
# ## loading the dataset

# %%
data=pd.read_csv("data_summer_course.csv")
pd.set_option('display.max_columns', None)
data.head(3)
# Out:
#    Mobile_Number  MAINACTBAL       LASTVCEUSGDATE       LASTRECHRGDATE  \
# 0       61159748      0.2630  04/16/2023 00:00:00     04-08-2023 00:00
# 1       17488035      0.1901  04/15/2023 00:00:00  03/26/2023 00:00:00
# 2       43749562      0.1243     04-01-2023 00:00  01/31/2023 00:00:00
#
#          FIRSTCALLDATE     DEVICETYPE ISDEVICE3GENABLED VASSUBSCRIBERFLAG  \
# 0  04/14/2022 00:00:00     Smartphone                 Y                 N
# 1  06/13/2007 00:00:00     Smartphone                 Y                 N
# 2  02/16/2022 00:00:00  Voice Centric                 N                 N
#
#   ISDEVICEDATAENABLED  AGEONNETWORK    LASTREVGENEVTDATE  \
# 0                   Y           368  04/16/2023 00:00:00
# 1                   Y          5786  04/15/2023 00:00:00
# 2                   N           425  02/13/2023 00:00:00
#
#    SUBSRIBERLASTBALANCE last_app_used CUSTSEGMENT  CNTCHURND1_30  \
# 0                0.2630    12-04-2023      Silver            NaN
# 1                0.1901           NaN        None            NaN
# 2                0.1243           NaN        None            2.0
#
#    HANDSETCHANGESFLAGD1_30 DEVICENETWORK                   DEVICEMODELC  \
# 0                      NaN            4G  Tecno Telecom KE5J/Spark 6 GO
# 1                      NaN           NaN                            NaN
# 2                      NaN           NaN                            NaN
#
#    DEVICEDUALSIMFLAG  ARPUD1_30  SUMVCEREVCD1_30  SUMDATAREVCD1_30  \
# 0                2.0      620.0        22.985625               0.0
# 1                NaN      100.0        26.570050               0.0
# 2                NaN        0.0              NaN               NaN
#
#    SUMDATAUSGCD1_30  SUMVOICEUSGCD1_30  SUMDATAUSG4GCD1_15  \
# 0      1.133457e+10            12878.0         275794501.0
# 1      0.000000e+00              652.0                 0.0
# 2               NaN                NaN                 NaN
#
#    SUMDATAUSG4GCD15_30 SMARTPHONEFLAG  MAINACTBAL1  CNTZEROBALCD_1  \
# 0         1.105682e+10              Y      0.26304               0
# 1         0.000000e+00              Y      0.19011               0
# 2                  NaN              N      0.12430               0
#
#     FIRSTREVGENEVTDATE
# 0  04/14/2022 00:00:00
# 1  06/14/2007 00:00:00
# 2  02/16/2022 00:00:00

# %%
data.shape
# Out:
# (200000, 30)

# %%
data.columns.values
# Out:
# array(['Mobile_Number', 'MAINACTBAL', 'LASTVCEUSGDATE', 'LASTRECHRGDATE',
#        'FIRSTCALLDATE', 'DEVICETYPE', 'ISDEVICE3GENABLED',
#        'VASSUBSCRIBERFLAG', 'ISDEVICEDATAENABLED', 'AGEONNETWORK',
#        'LASTREVGENEVTDATE', 'SUBSRIBERLASTBALANCE', 'last_app_used',
#        'CUSTSEGMENT', 'CNTCHURND1_30', 'HANDSETCHANGESFLAGD1_30',
#        'DEVICENETWORK', 'DEVICEMODELC', 'DEVICEDUALSIMFLAG', 'ARPUD1_30',
#        'SUMVCEREVCD1_30', 'SUMDATAREVCD1_30', 'SUMDATAUSGCD1_30',
#        'SUMVOICEUSGCD1_30', 'SUMDATAUSG4GCD1_15', 'SUMDATAUSG4GCD15_30',
#        'SMARTPHONEFLAG', 'MAINACTBAL1', 'CNTZEROBALCD_1',
#        'FIRSTREVGENEVTDATE'], dtype=object)

# %%
data.dtypes
# Out:
# Mobile_Number                int64
# MAINACTBAL                 float64
# LASTVCEUSGDATE              object
# LASTRECHRGDATE              object
# FIRSTCALLDATE               object
# DEVICETYPE                  object
# ISDEVICE3GENABLED           object
# VASSUBSCRIBERFLAG           object
# ISDEVICEDATAENABLED         object
# AGEONNETWORK                 int64
# LASTREVGENEVTDATE           object
# SUBSRIBERLASTBALANCE       float64
# last_app_used               object
# CUSTSEGMENT                 object
# CNTCHURND1_30              float64
# HANDSETCHANGESFLAGD1_30    float64
# DEVICENETWORK               object
# DEVICEMODELC                object
# DEVICEDUALSIMFLAG          float64
# ARPUD1_30                  float64
# SUMVCEREVCD1_30            float64
# SUMDATAREVCD1_30           float64
# SUMDATAUSGCD1_30           float64
# SUMVOICEUSGCD1_30          float64
# SUMDATAUSG4GCD1_15         float64
# SUMDATAUSG4GCD15_30        float64
# SMARTPHONEFLAG              object
# MAINACTBAL1                float64
# CNTZEROBALCD_1               int64
# FIRSTREVGENEVTDATE          object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Mobile_Number                   0
# MAINACTBAL                      0
# LASTVCEUSGDATE                 19
# LASTRECHRGDATE                148
# FIRSTCALLDATE                  19
# DEVICETYPE                      0
# ISDEVICE3GENABLED               0
# VASSUBSCRIBERFLAG               0
# ISDEVICEDATAENABLED             0
# AGEONNETWORK                    0
# LASTREVGENEVTDATE               0
# SUBSRIBERLASTBALANCE            0
# last_app_used              120164
# CUSTSEGMENT                     0
# CNTCHURND1_30              110863
# HANDSETCHANGESFLAGD1_30    164493
# DEVICENETWORK               78356
# DEVICEMODELC                78356
# DEVICEDUALSIMFLAG           78356
# ARPUD1_30                       0
# SUMVCEREVCD1_30             45119
# SUMDATAREVCD1_30            48283
# SUMDATAUSGCD1_30            44858
# SUMVOICEUSGCD1_30           44858
# SUMDATAUSG4GCD1_15          50208
# SUMDATAUSG4GCD15_30         47992
# SMARTPHONEFLAG                  0
# MAINACTBAL1                     0
# CNTZEROBALCD_1                  0
# FIRSTREVGENEVTDATE              0
# dtype: int64

# %%
data.describe()
# Out:
#        Mobile_Number     MAINACTBAL   AGEONNETWORK  SUBSRIBERLASTBALANCE  \
# count   2.000000e+05  200000.000000  200000.000000         200000.000000
# mean    4.543535e+07      11.007088    1993.406405             11.007088
# std     2.900110e+07      48.991782    1774.404666             48.991782
# min     2.435000e+03       0.000000     101.000000              0.000000
# 25%     2.015619e+07       0.008600     531.000000              0.008600
# 50%     4.208031e+07       0.141900    1369.000000              0.141900
# 75%     6.797840e+07       8.298200    3129.000000              8.298200
# max     9.998810e+07    4909.386900    6638.000000           4909.386900
#
#        CNTCHURND1_30  HANDSETCHANGESFLAGD1_30  DEVICEDUALSIMFLAG  \
# count   89137.000000             35507.000000       121644.00000
# mean        1.843398                 1.364942            1.99649
# std         1.031201                 0.789854            0.44538
# min         1.000000                 1.000000            1.00000
# 25%         1.000000                 1.000000            2.00000
# 50%         2.000000                 1.000000            2.00000
# 75%         2.000000                 2.000000            2.00000
# max         8.000000                30.000000            6.00000
#
#            ARPUD1_30  SUMVCEREVCD1_30  SUMDATAREVCD1_30  SUMDATAUSGCD1_30  \
# count  200000.000000    154881.000000     151717.000000      1.551420e+05
# mean      176.082796        43.608401          2.491229      4.339755e+09
# std       297.788781        87.563824          6.910859      1.172871e+10
# min         0.000000         0.000000          0.000000      0.000000e+00
# 25%         0.000000         0.000000          0.000000      0.000000e+00
# 50%        58.000000         9.217591          0.000000      1.327200e+04
# 75%       216.000000        50.621675          0.455455      1.666354e+09
# max      9251.000000      5313.730175        225.059835      2.380000e+11
#
#        SUMVOICEUSGCD1_30  SUMDATAUSG4GCD1_15  SUMDATAUSG4GCD15_30  \
# count      155142.000000        1.497920e+05         1.520080e+05
# mean         7641.116912        1.875772e+09         2.041547e+09
# std         13910.996894        5.541392e+09         5.982678e+09
# min             0.000000        0.000000e+00         0.000000e+00
# 25%           435.000000        0.000000e+00         0.000000e+00
# 50%          2573.000000        0.000000e+00         0.000000e+00
# 75%          8977.750000        9.751026e+07         1.794456e+08
# max        666309.000000        1.590000e+11         1.050000e+11
#
#          MAINACTBAL1  CNTZEROBALCD_1
# count  200000.000000   200000.000000
# mean       11.007088        0.003020
# std        48.991782        0.054872
# min         0.000000        0.000000
# 25%         0.008610        0.000000
# 50%         0.141880        0.000000
# 75%         8.298160        0.000000
# max      4909.386700        1.000000

# %% [markdown]
# ## Data Preprocessing
# ### Handling the missing values and drop the columns

# %%
# How many columns have most Null values in percentage.  
percent_of_null_values = (data.isnull().sum()/ data.shape[0]) *100
print(percent_of_null_values)
# Out:
# Mobile_Number               0.0000
# MAINACTBAL                  0.0000
# LASTVCEUSGDATE              0.0095
# LASTRECHRGDATE              0.0740
# FIRSTCALLDATE               0.0095
# DEVICETYPE                  0.0000
# ISDEVICE3GENABLED           0.0000
# VASSUBSCRIBERFLAG           0.0000
# ISDEVICEDATAENABLED         0.0000
# AGEONNETWORK                0.0000
# LASTREVGENEVTDATE           0.0000
# SUBSRIBERLASTBALANCE        0.0000
# last_app_used              60.0820
# CUSTSEGMENT                 0.0000
# CNTCHURND1_30              55.4315
# HANDSETCHANGESFLAGD1_30    82.2465
# DEVICENETWORK              39.1780
# DEVICEMODELC               39.1780
# DEVICEDUALSIMFLAG          39.1780
# ARPUD1_30                   0.0000
# SUMVCEREVCD1_30            22.5595
# SUMDATAREVCD1_30           24.1415
# SUMDATAUSGCD1_30           22.4290
# SUMVOICEUSGCD1_30          22.4290
# SUMDATAUSG4GCD1_15         25.1040
# SUMDATAUSG4GCD15_30        23.9960
# SMARTPHONEFLAG              0.0000
# MAINACTBAL1                 0.0000
# CNTZEROBALCD_1              0.0000
# FIRSTREVGENEVTDATE          0.0000
# dtype: float64

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
data['SUMDATAUSG4GCD1_30'] = data['SUMDATAUSG4GCD1_15'] + data['SUMDATAUSG4GCD15_30']

column1 = 'SUMDATAUSG4GCD1_30'
column2 =  'SUMDATAUSGCD1_30'
correlation1 = data[column1].corr(data[column2])
print(correlation1)
# Out:
# 0.9805993861103685

# %%
column_name = ['SUMDATAUSG4GCD1_30', 'SUMDATAUSG4GCD1_15' , 'SUMDATAUSG4GCD15_30']
data.drop(columns=column_name, inplace=True)

# %%
column1 = 'MAINACTBAL1'
column2 = 'MAINACTBAL'
column3 =  'SUBSRIBERLASTBALANCE'
correlation1 = data[column1].corr(data[column3])
# Computed the correlation between the two columns 
correlation2 = data[column1].corr(data[column2])
print(correlation1, correlation2)
# Out:
# 0.9999999999998238 0.9999999999998238

# %%
columns_name = ['MAINACTBAL1','SUBSRIBERLASTBALANCE']
data.drop(columns=columns_name, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Mobile_Number            200000 non-null  int64
#  1   MAINACTBAL               200000 non-null  float64
#  2   LASTVCEUSGDATE           199981 non-null  object
#  3   LASTRECHRGDATE           199852 non-null  object
#  4   FIRSTCALLDATE            199981 non-null  object
#  5   DEVICETYPE               200000 non-null  object
#  6   ISDEVICE3GENABLED        200000 non-null  object
#  7   VASSUBSCRIBERFLAG        200000 non-null  object
#  8   ISDEVICEDATAENABLED      200000 non-null  object
#  9   AGEONNETWORK             200000 non-null  int64
#  10  LASTREVGENEVTDATE        200000 non-null  object
#  11  last_app_used            79836 non-null   object
#  12  CUSTSEGMENT              200000 non-null  object
#  13  CNTCHURND1_30            89137 non-null   float64
#  14  HANDSETCHANGESFLAGD1_30  35507 non-null   float64
#  15  DEVICENETWORK            121644 non-null  object
#  16  DEVICEMODELC             121644 non-null  object
#  17  DEVICEDUALSIMFLAG        121644 non-null  float64
#  18  ARPUD1_30                200000 non-null  float64
#  19  SUMVCEREVCD1_30          154881 non-null  float64
#  20  SUMDATAREVCD1_30         151717 non-null  float64
#  21  SUMDATAUSGCD1_30         155142 non-null  float64
#  22  SUMVOICEUSGCD1_30        155142 non-null  float64
#  23  SMARTPHONEFLAG           200000 non-null  object
#  24  CNTZEROBALCD_1           200000 non-null  int64
#  25  FIRSTREVGENEVTDATE       200000 non-null  object
# dtypes: float64(9), int64(3), object(14)
# memory usage: 39.7+ MB

# %%
missing_numerical_var = ['SUMVCEREVCD1_30', 'SUMDATAREVCD1_30','SUMDATAUSGCD1_30', 'SUMVOICEUSGCD1_30']
plt.figure(figsize=(10,10))
sns.set()

for i, var in enumerate(missing_numerical_var):
    plt.subplot(2,2,i+1)
    sns.distplot(data[var], bins=50, kde_kws={'linewidth':2, 'color':'#DC143C'})
plt.show()

# %%
# Numerical column
# Filling the null values or empty cell with mean value
copy_data_mean = data.copy();
copy_data_median = data.copy();

pp = data[missing_numerical_var].describe()
print(pp)
# In Null values we are entering the mean value.
for column in missing_numerical_var:
    copy_data_mean[column] = copy_data_mean[column].fillna(copy_data_mean[column].mean())
    
#In null values we are filling the median values
for column in missing_numerical_var:
    copy_data_median[column] = copy_data_median[column].fillna(copy_data_median[column].median())
# Out:
#        SUMVCEREVCD1_30  SUMDATAREVCD1_30  SUMDATAUSGCD1_30  SUMVOICEUSGCD1_30
# count    154881.000000     151717.000000      1.551420e+05      155142.000000
# mean         43.608401          2.491229      4.339755e+09        7641.116912
# std          87.563824          6.910859      1.172871e+10       13910.996894
# min           0.000000          0.000000      0.000000e+00           0.000000
# 25%           0.000000          0.000000      0.000000e+00         435.000000
# 50%           9.217591          0.000000      1.327200e+04        2573.000000
# 75%          50.621675          0.455455      1.666354e+09        8977.750000
# max        5313.730175        225.059835      2.380000e+11      666309.000000

# %%
'''plt.figure(figsize=(10,10))
sns.get()
for i, var in enumerate(missing_numerical_var):
    plt.subplot(2,2,i+1)
    sns.distplot(data[var], bins=50, kde_kws={'linewidth':2, 'color':'red'}, label = 'original')
    sns.distplot(copy_data_mean[var], bins=50, kde_kws={'linewidth':2, 'color':'green'}, label ='mean')
    sns.distplot(copy_data_median[var], bins=50, kde_kws={'linewidth':2, 'color':'purple'}, label = 'median')
    plt.legend()  
plt.show()   '''
# Out:
# "plt.figure(figsize=(10,10))\nsns.get()\nfor i, var in enumerate(missing_numerical_var):\n    plt.subplot(2,2,i+1)\n    sns.distplot(data[var], bins=50, kde_kws={'linewidth':2, 'color':'red'}, label = 'original')\n    sns.distplot(copy_data_mean[var], bins=50, kde_kws={'linewidth':2, 'color':'green'}, label ='mean')\n    sns.distplot(copy_data_median[var], bins=50, kde_kws={'linewidth':2, 'color':'purple'}, label = 'median')\n    plt.legend()  \nplt.show()   "

# %%
data = copy_data_median.copy()

# %%
#columns has been stored in this DataFrame 'deleted_columns' for later use if needed
dup_data = data.copy()
columns_to_extract = ['DEVICEDUALSIMFLAG', 'DEVICEMODELC', 'DEVICENETWORK','last_app_used','FIRSTCALLDATE', 'Mobile_Number', 'FIRSTREVGENEVTDATE']
deleted_columns = data[columns_to_extract].copy()
data.drop(columns=columns_to_extract, inplace=True)

# %%
data['LASTVCEUSGDATE'] = pd.to_datetime(data['LASTVCEUSGDATE'])  
mode_date = data['LASTVCEUSGDATE'].mode()[0] 
data['LASTVCEUSGDATE'].fillna(mode_date, inplace=True)

data['LASTRECHRGDATE'] = pd.to_datetime(data['LASTRECHRGDATE']) 
mode_date = data['LASTRECHRGDATE'].mode()[0] 
data['LASTRECHRGDATE'].fillna(mode_date, inplace=True)

data['LASTREVGENEVTDATE'] = pd.to_datetime(data['LASTREVGENEVTDATE'])

# %%
data['HANDSETCHANGESFLAGD1_30'].value_counts()
# Out:
# 1.0     25981
# 2.0      7314
# 3.0      1586
# 4.0       399
# 5.0       121
# 6.0        46
# 7.0        16
# 8.0        10
# 9.0         9
# 10.0        7
# 11.0        4
# 13.0        3
# 15.0        2
# 30.0        2
# 14.0        2
# 16.0        2
# 12.0        2
# 21.0        1
# Name: HANDSETCHANGESFLAGD1_30, dtype: int64

# %%
column_name = 'HANDSETCHANGESFLAGD1_30'

# Fill the missing (NaN) values in the column with 0
data[column_name].fillna(0, inplace=True)

# %%
data['CHURN_PREDICTION'] = data['CNTCHURND1_30'].apply(lambda x: 1 if pd.notnull(x) else 0)

# %%
# churn has been stored in this series for later use: churn_deleted_col
churn_deleted_col = data['CNTCHURND1_30']
data['CNTCHURND1_30'].fillna(0, inplace=True)

# %%
data.rename(columns={'CNTCHURND1_30': 'CNTCHURN_FLAG'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MAINACTBAL               200000 non-null  float64
#  1   LASTVCEUSGDATE           200000 non-null  datetime64[ns]
#  2   LASTRECHRGDATE           200000 non-null  datetime64[ns]
#  3   DEVICETYPE               200000 non-null  object
#  4   ISDEVICE3GENABLED        200000 non-null  object
#  5   VASSUBSCRIBERFLAG        200000 non-null  object
#  6   ISDEVICEDATAENABLED      200000 non-null  object
#  7   AGEONNETWORK             200000 non-null  int64
#  8   LASTREVGENEVTDATE        200000 non-null  datetime64[ns]
#  9   CUSTSEGMENT              200000 non-null  object
#  10  CNTCHURN_FLAG            200000 non-null  float64
#  11  HANDSETCHANGESFLAGD1_30  200000 non-null  float64
#  12  ARPUD1_30                200000 non-null  float64
#  13  SUMVCEREVCD1_30          200000 non-null  float64
#  14  SUMDATAREVCD1_30         200000 non-null  float64
#  15  SUMDATAUSGCD1_30         200000 non-null  float64
#  16  SUMVOICEUSGCD1_30        200000 non-null  float64
#  17  SMARTPHONEFLAG           200000 non-null  object
#  18  CNTZEROBALCD_1           200000 non-null  int64
#  19  CHURN_PREDICTION         200000 non-null  int64
# dtypes: datetime64[ns](3), float64(8), int64(3), object(6)
# memory usage: 30.5+ MB

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
data['CNTCHURN_FLAG'].isnull().sum()
# Out:
# 0

# %%
fig = plt.figure(figsize=(12, 6)) 
ax = fig.add_subplot(111)
prop_response = data['CNTCHURN_FLAG'].value_counts(normalize=True)

# create a bar plot showing the proportion of churning customers in next 30 days

prop_response.plot(kind='bar',ax=ax, color=['darkorange'])
ax.set_title('Proportion of observations of the response variable',fontsize=18, loc='left')
ax.set_xlabel('Churning days ',fontsize=14)
ax.set_ylabel('proportion of observations of churn in next 30 days',fontsize=14)
ax.tick_params(rotation='auto')

# eliminate the frame from the plot

s_names = ('top', 'right', 'bottom', 'left')
for spine_name in s_names:
    ax.spines[spine_name].set_visible(False)
plt.show()

# %%
pie_data = data['CHURN_PREDICTION'].value_counts()
pie_data.plot(kind='pie', autopct='%1.1f%%', startangle=90)

# Add title and label for better visualization
plt.title('Pie Chart of COLUMN_NAME')
plt.ylabel('') 
# Show the plot
plt.show()

# %%
pie_data = data['CNTCHURN_FLAG'].value_counts()
pie_data.plot(kind='pie', autopct='%1.1f%%', startangle=90)

# Add title and label for better visualization
plt.title('Pie Chart of COLUMN_NAME')
plt.ylabel('') 
# Show the plot
plt.show()

# %%
df = data.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MAINACTBAL               200000 non-null  float64
#  1   LASTVCEUSGDATE           200000 non-null  datetime64[ns]
#  2   LASTRECHRGDATE           200000 non-null  datetime64[ns]
#  3   DEVICETYPE               200000 non-null  object
#  4   ISDEVICE3GENABLED        200000 non-null  object
#  5   VASSUBSCRIBERFLAG        200000 non-null  object
#  6   ISDEVICEDATAENABLED      200000 non-null  object
#  7   AGEONNETWORK             200000 non-null  int64
#  8   LASTREVGENEVTDATE        200000 non-null  datetime64[ns]
#  9   CUSTSEGMENT              200000 non-null  object
#  10  CNTCHURN_FLAG            200000 non-null  float64
#  11  HANDSETCHANGESFLAGD1_30  200000 non-null  float64
#  12  ARPUD1_30                200000 non-null  float64
#  13  SUMVCEREVCD1_30          200000 non-null  float64
#  14  SUMDATAREVCD1_30         200000 non-null  float64
#  15  SUMDATAUSGCD1_30         200000 non-null  float64
#  16  SUMVOICEUSGCD1_30        200000 non-null  float64
#  17  SMARTPHONEFLAG           200000 non-null  object
#  18  CNTZEROBALCD_1           200000 non-null  int64
#  19  CHURN_PREDICTION         200000 non-null  int64
# dtypes: datetime64[ns](3), float64(8), int64(3), object(6)
# memory usage: 30.5+ MB

# %% [markdown]
# # Feature Engineering

# %%
# 1. Date Features

date_columns = ['LASTVCEUSGDATE', 'LASTRECHRGDATE', 'LASTREVGENEVTDATE']

# 2. Age on Network
def age_group(age):
    if age <= 180:  # 0-6 months
        return '0-6 months'
    elif age <= 365:  # 6-12 months
        return '6-12 months'
    elif age <= 730:  # 1-2 years
        return '1-2 years'
    else:
        return '2+ years'

df['AGEONNETWORK_group'] = df['AGEONNETWORK'].apply(age_group)

# 3. Usage Ratio
df['USAGE_RATIO'] = df['SUMDATAREVCD1_30'] / df['SUMVCEREVCD1_30']

# 4. Total Revenue
df['TOTAL_REVENUE'] = df['SUMVCEREVCD1_30'] + df['SUMDATAREVCD1_30'] + df['ARPUD1_30']

# 5. Interaction Features
df['DATA_USAGE_IMPACT'] = df['SUMDATAREVCD1_30'] * df['SUMDATAUSGCD1_30']

# 6. Time Since Last Event
current_date = pd.to_datetime('today')

for column in date_columns:
    df[column + '_since'] = (current_date - df[column]).dt.days

# 7. Usage Percentiles
usage_columns = ['SUMDATAREVCD1_30', 'SUMDATAUSGCD1_30', 'SUMVCEREVCD1_30', 'SUMVOICEUSGCD1_30']

for column in usage_columns:
    df[column + '_percentile'] = df[column].rank(pct=True)

# Now, 'df' contains the dataset with the new engineered features.

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   MAINACTBAL                    200000 non-null  float64
#  1   LASTVCEUSGDATE                200000 non-null  datetime64[ns]
#  2   LASTRECHRGDATE                200000 non-null  datetime64[ns]
#  3   DEVICETYPE                    200000 non-null  object
#  4   ISDEVICE3GENABLED             200000 non-null  object
#  5   VASSUBSCRIBERFLAG             200000 non-null  object
#  6   ISDEVICEDATAENABLED           200000 non-null  object
#  7   AGEONNETWORK                  200000 non-null  int64
#  8   LASTREVGENEVTDATE             200000 non-null  datetime64[ns]
#  9   CUSTSEGMENT                   200000 non-null  object
#  10  CNTCHURN_FLAG                 200000 non-null  float64
#  11  HANDSETCHANGESFLAGD1_30       200000 non-null  float64
#  12  ARPUD1_30                     200000 non-null  float64
#  13  SUMVCEREVCD1_30               200000 non-null  float64
#  14  SUMDATAREVCD1_30              200000 non-null  float64
#  15  SUMDATAUSGCD1_30              200000 non-null  float64
#  16  SUMVOICEUSGCD1_30             200000 non-null  float64
#  17  SMARTPHONEFLAG                200000 non-null  object
#  18  CNTZEROBALCD_1                200000 non-null  int64
#  19  CHURN_PREDICTION              200000 non-null  int64
#  20  AGEONNETWORK_group            200000 non-null  object
#  21  USAGE_RATIO                   152678 non-null  float64
#  22  TOTAL_REVENUE                 200000 non-null  float64
#  23  DATA_USAGE_IMPACT             200000 non-null  float64
#  24  LASTVCEUSGDATE_since          200000 non-null  int64
#  25  LASTRECHRGDATE_since          200000 non-null  int64
#  26  LASTREVGENEVTDATE_since       200000 non-null  int64
#  27  SUMDATAREVCD1_30_percentile   200000 non-null  float64
#  28  SUMDATAUSGCD1_30_percentile   200000 non-null  float64
#  29  SUMVCEREVCD1_30_percentile    200000 non-null  float64
#  30  SUMVOICEUSGCD1_30_percentile  200000 non-null  float64
# dtypes: datetime64[ns](3), float64(15), int64(6), object(7)
# memory usage: 47.3+ MB

# %%
df.columns
# Out:
# Index(['MAINACTBAL', 'LASTVCEUSGDATE', 'LASTRECHRGDATE', 'DEVICETYPE',
#        'ISDEVICE3GENABLED', 'VASSUBSCRIBERFLAG', 'ISDEVICEDATAENABLED',
#        'AGEONNETWORK', 'LASTREVGENEVTDATE', 'CUSTSEGMENT', 'CNTCHURN_FLAG',
#        'HANDSETCHANGESFLAGD1_30', 'ARPUD1_30', 'SUMVCEREVCD1_30',
#        'SUMDATAREVCD1_30', 'SUMDATAUSGCD1_30', 'SUMVOICEUSGCD1_30',
#        'SMARTPHONEFLAG', 'CNTZEROBALCD_1', 'CHURN_PREDICTION',
#        'AGEONNETWORK_group', 'USAGE_RATIO', 'TOTAL_REVENUE',
#        'DATA_USAGE_IMPACT', 'LASTVCEUSGDATE_since', 'LASTRECHRGDATE_since',
#        'LASTREVGENEVTDATE_since', 'SUMDATAREVCD1_30_percentile',
#        'SUMDATAUSGCD1_30_percentile', 'SUMVCEREVCD1_30_percentile',
#        'SUMVOICEUSGCD1_30_percentile'],
#       dtype='object')

# %%
numeric_columns = ['MAINACTBAL', 'ARPUD1_30', 'SUMVCEREVCD1_30', 'SUMDATAREVCD1_30',
                   'SUMDATAUSGCD1_30', 'SUMVOICEUSGCD1_30','TOTAL_REVENUE',
                   'DATA_USAGE_IMPACT','LASTVCEUSGDATE_since', 'LASTRECHRGDATE_since','LASTREVGENEVTDATE_since', 'SUMDATAREVCD1_30_percentile',
                   'SUMDATAUSGCD1_30_percentile', 'SUMVCEREVCD1_30_percentile','SUMVOICEUSGCD1_30_percentile']
categorical_columns = ['DEVICETYPE', 'ISDEVICE3GENABLED', 'VASSUBSCRIBERFLAG', 'ISDEVICEDATAENABLED',
                        'AGEONNETWORK_group','SMARTPHONEFLAG','HANDSETCHANGESFLAGD1_30','CUSTSEGMENT']

# %%
for column in numeric_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[column], bins=20, kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Step 3: Univariate Analysis - Categorical Features
'''for i, column in enumerate(categorical_columns, 1):
    plt.figure(figsize=(5, 3))
    sns.countplot(df[column])
    plt.title(column)

plt.tight_layout()
plt.show()'''
# Out:
# 'for i, column in enumerate(categorical_columns, 1):\n    plt.figure(figsize=(5, 3))\n    sns.countplot(df[column])\n    plt.title(column)\n\nplt.tight_layout()\nplt.show()'

# %% [markdown]
# ## Bivariate Analysis

# %%
# Step 4: Bivariate Analysis - Churn vs. Numeric Features
for i, column in enumerate(numeric_columns, 1):
    plt.figure(figsize=(8, 5))
    sns.boxplot(x='CNTCHURN_FLAG', y=column, data=df)
    plt.title(f'Churn vs. {column}')

plt.tight_layout()
plt.show()

# %%
# Step 5: Bivariate Analysis - Churn vs. Categorical Features
for i, column in enumerate(categorical_columns, 1):
    plt.figure(figsize=(8, 5))
    sns.countplot(x=column, hue='CNTCHURN_FLAG', data=df)
    plt.title(f'Churn vs. {column}')

plt.tight_layout()
plt.show()

# %%
for column in categorical_columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=df, x=column, hue='CHURN_PREDICTION')
    plt.title(f'Distribution of {column} by Churn')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.legend(title='Churn Prediction', labels=['Non-Churn', 'Churn'])
    plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(data=df[numeric_columns])
plt.title('Boxplot of Numerical Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Step 6: Correlation Matrix
correlation_matrix = df.corr()
plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
'''sns.pairplot(df[numeric_columns])
plt.suptitle('Pair Plot of Numerical Features')
plt.tight_layout()
plt.show()'''
# Out:
# "sns.pairplot(df[numeric_columns])\nplt.suptitle('Pair Plot of Numerical Features')\nplt.tight_layout()\nplt.show()"

# %%
df.drop(columns=date_columns,inplace=True)

# %%
print(df)
# Out:
#         MAINACTBAL     DEVICETYPE ISDEVICE3GENABLED VASSUBSCRIBERFLAG  \
# 0           0.2630     Smartphone                 Y                 N
# 1           0.1901     Smartphone                 Y                 N
# 2           0.1243  Voice Centric                 N                 N
# 3           1.6096     Smartphone                 Y                 N
# 4           5.1838  Voice Centric                 N                 N
# ...            ...            ...               ...               ...
# 199995      0.0118     Smartphone                 Y                 N
# 199996     17.3471     Smartphone                 Y                 N
# 199997      0.0089     Smartphone                 Y                 N
# 199998     10.2243     Smartphone                 Y                 N
# 199999      0.0719  Voice Centric                 N                 N
#
#        ISDEVICEDATAENABLED  AGEONNETWORK CUSTSEGMENT  CNTCHURN_FLAG  \
# 0                        Y           368      Silver            0.0
# 1                        Y          5786        None            0.0
# 2                        N           425        None            2.0
# 3                        Y          3570        None            3.0
# 4                        N          3999        None            0.0
# ...                    ...           ...         ...            ...
# 199995                   Y          1341        None            2.0
# 199996                   Y           760        None            2.0
# 199997                   Y           863        None            1.0
# 199998                   Y          5429        None            0.0
# 199999                   N           196        None            1.0
#
#         HANDSETCHANGESFLAGD1_30  ARPUD1_30  SUMVCEREVCD1_30  SUMDATAREVCD1_30  \
# 0                           0.0      620.0        22.985625          0.000000
# 1                           0.0      100.0        26.570050          0.000000
# 2                           0.0        0.0         9.217591          0.000000
# 3                           1.0       91.0        30.480910          0.520520
# 4                           0.0       88.0        95.027229          0.000000
# ...                         ...        ...              ...               ...
# 199995                      0.0       18.0         0.000000          0.000000
# 199996                      0.0       45.0        32.313125          6.662656
# 199997                      1.0      295.0         0.000000          0.000000
# 199998                      0.0        0.0         9.217591          0.000000
# 199999                      0.0        0.0         0.000000          0.000000
#
#         SUMDATAUSGCD1_30  SUMVOICEUSGCD1_30 SMARTPHONEFLAG  CNTZEROBALCD_1  \
# 0           1.133457e+10            12878.0              Y               0
# 1           0.000000e+00              652.0              Y               0
# 2           1.327200e+04             2573.0              N               0
# 3           4.288550e+05             2721.0              Y               0
# 4           0.000000e+00             3123.0              N               0
# ...                  ...                ...            ...             ...
# 199995      2.153636e+09                0.0              Y               0
# 199996      6.594667e+06              893.0              Y               0
# 199997      1.600963e+09            16891.0              Y               0
# 199998      1.327200e+04             2573.0              Y               0
# 199999      0.000000e+00                0.0              N               0
#
#         CHURN_PREDICTION AGEONNETWORK_group  USAGE_RATIO  TOTAL_REVENUE  \
# 0                      0          1-2 years     0.000000     642.985625
# 1                      0           2+ years     0.000000     126.570050
# 2                      1          1-2 years     0.000000       9.217591
# 3                      1           2+ years     0.017077     122.001430
# 4                      0           2+ years     0.000000     183.027229
# ...                  ...                ...          ...            ...
# 199995                 1           2+ years          NaN      18.000000
# 199996                 1           2+ years     0.206190      83.975781
# 199997                 1           2+ years          NaN     295.000000
# 199998                 0           2+ years     0.000000       9.217591
# 199999                 1        6-12 months          NaN       0.000000
#
#         DATA_USAGE_IMPACT  LASTVCEUSGDATE_since  LASTRECHRGDATE_since  \
# 0            0.000000e+00                   141                   149
# 1            0.000000e+00                   142                   162
# 2            0.000000e+00                   156                   216
# 3            2.232276e+05                   141                   146
# 4            0.000000e+00                   141                   147
# ...                   ...                   ...                   ...
# 199995       0.000000e+00                   141                   148
# 199996       4.393800e+07                   141                   155
# 199997       0.000000e+00                   141                   142
# 199998       0.000000e+00                   141                   193
# 199999       0.000000e+00                   141                   184
#
#         LASTREVGENEVTDATE_since  SUMDATAREVCD1_30_percentile  \
# 0                           141                     0.349092
# 1                           142                     0.349092
# 2                           203                     0.349092
# 3                           143                     0.812368
# 4                           141                     0.349092
# ...                         ...                          ...
# 199995                      143                     0.349092
# 199996                      141                     0.898657
# 199997                      141                     0.349092
# 199998                      142                     0.349092
# 199999                      155                     0.349092
#
#         SUMDATAUSGCD1_30_percentile  SUMVCEREVCD1_30_percentile  \
# 0                          0.910580                    0.702695
# 1                          0.154397                    0.719137
# 2                          0.500000                    0.500003
# 3                          0.670970                    0.739985
# 4                          0.154397                    0.888095
# ...                             ...                         ...
# 199995                     0.818110                    0.143503
# 199996                     0.709025                    0.747020
# 199997                     0.803765                    0.143503
# 199998                     0.500000                    0.500003
# 199999                     0.154397                    0.143503
#
#         SUMVOICEUSGCD1_30_percentile
# 0                           0.859975
# 1                           0.224500
# 2                           0.500005
# 3                           0.620302
# 4                           0.640310
# ...                              ...
# 199995                      0.051445
# 199996                      0.258147
# 199997                      0.897250
# 199998                      0.500005
# 199999                      0.051445
#
# [200000 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   MAINACTBAL                    200000 non-null  float64
#  1   DEVICETYPE                    200000 non-null  object
#  2   ISDEVICE3GENABLED             200000 non-null  object
#  3   VASSUBSCRIBERFLAG             200000 non-null  object
#  4   ISDEVICEDATAENABLED           200000 non-null  object
#  5   AGEONNETWORK                  200000 non-null  int64
#  6   CUSTSEGMENT                   200000 non-null  object
#  7   CNTCHURN_FLAG                 200000 non-null  float64
#  8   HANDSETCHANGESFLAGD1_30       200000 non-null  float64
#  9   ARPUD1_30                     200000 non-null  float64
#  10  SUMVCEREVCD1_30               200000 non-null  float64
#  11  SUMDATAREVCD1_30              200000 non-null  float64
#  12  SUMDATAUSGCD1_30              200000 non-null  float64
#  13  SUMVOICEUSGCD1_30             200000 non-null  float64
#  14  SMARTPHONEFLAG                200000 non-null  object
#  15  CNTZEROBALCD_1                200000 non-null  int64
#  16  CHURN_PREDICTION              200000 non-null  int64
#  17  AGEONNETWORK_group            200000 non-null  object
#  18  USAGE_RATIO                   152678 non-null  float64
#  19  TOTAL_REVENUE                 200000 non-null  float64
#  20  DATA_USAGE_IMPACT             200000 non-null  float64
#  21  LASTVCEUSGDATE_since          200000 non-null  int64
#  22  LASTRECHRGDATE_since          200000 non-null  int64
#  23  LASTREVGENEVTDATE_since       200000 non-null  int64
#  24  SUMDATAREVCD1_30_percentile   200000 non-null  float64
#  25  SUMDATAUSGCD1_30_percentile   200000 non-null  float64
#  26  SUMVCEREVCD1_30_percentile    200000 non-null  float64
#  27  SUMVOICEUSGCD1_30_percentile  200000 non-null  float64
# dtypes: float64(15), int64(6), object(7)
# memory usage: 42.7+ MB

# %%
df.to_csv('new_data.csv', index=False)

# %% [markdown]
# # Changing the object types to numerical

# %%
final_copy=df.copy()
final_copy.drop(columns=['SUMDATAREVCD1_30_percentile','SUMDATAUSGCD1_30_percentile','SUMVCEREVCD1_30_percentile','SUMVOICEUSGCD1_30_percentile'],inplace=True)
# Changing the column containing Y & N to 0 & 1

# %%
columns_having_yn=['ISDEVICE3GENABLED','VASSUBSCRIBERFLAG','ISDEVICEDATAENABLED','SMARTPHONEFLAG']
mapping = {'Y': 1, 'N': 0}

# Loop through each column and use the map function to convert the values
for col in columns_having_yn:
    final_copy[col] = final_copy[col].map(mapping)

# %%
final_copy.drop(columns='USAGE_RATIO',inplace=True)

# %%
# changing AGEONNETWORK_group to '0-6 months'->1, '6-12 months'->2,   '1-2 years'->3,
#'1-2 years'->4, '2+ years'->5
final_copy.drop(columns='AGEONNETWORK',inplace=True)

# %%
mapping={'0-6 months':1, '6-12 months':2, '1-2 years':3, '2+ years':4}
final_copy['AGEONNETWORK_group']=final_copy['AGEONNETWORK_group'].map(mapping)

# %%
mapping={'None':0, 'Basic':1,   'Silver':2,'Gold':3, 'Platinum':4,'Signature':5}
final_copy['CUSTSEGMENT']=final_copy['CUSTSEGMENT'].map(mapping)

# %%
mapping={'Feature +':2,'Smartphone':1,'Voice Centric':0}
final_copy['DEVICETYPE']=final_copy['DEVICETYPE'].map(mapping)

# %%
final_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   MAINACTBAL               200000 non-null  float64
#  1   DEVICETYPE               200000 non-null  int64
#  2   ISDEVICE3GENABLED        200000 non-null  int64
#  3   VASSUBSCRIBERFLAG        200000 non-null  int64
#  4   ISDEVICEDATAENABLED      200000 non-null  int64
#  5   CUSTSEGMENT              200000 non-null  int64
#  6   CNTCHURN_FLAG            200000 non-null  float64
#  7   HANDSETCHANGESFLAGD1_30  200000 non-null  float64
#  8   ARPUD1_30                200000 non-null  float64
#  9   SUMVCEREVCD1_30          200000 non-null  float64
#  10  SUMDATAREVCD1_30         200000 non-null  float64
#  11  SUMDATAUSGCD1_30         200000 non-null  float64
#  12  SUMVOICEUSGCD1_30        200000 non-null  float64
#  13  SMARTPHONEFLAG           200000 non-null  int64
#  14  CNTZEROBALCD_1           200000 non-null  int64
#  15  CHURN_PREDICTION         200000 non-null  int64
#  16  AGEONNETWORK_group       200000 non-null  int64
#  17  TOTAL_REVENUE            200000 non-null  float64
#  18  DATA_USAGE_IMPACT        200000 non-null  float64
#  19  LASTVCEUSGDATE_since     200000 non-null  int64
#  20  LASTRECHRGDATE_since     200000 non-null  int64
#  21  LASTREVGENEVTDATE_since  200000 non-null  int64
# dtypes: float64(10), int64(12)
# memory usage: 33.6 MB

# %%
df_x=final_copy.copy()

# %%
X = df_x.drop(columns=['CNTCHURN_FLAG','CHURN_PREDICTION'])

# select dependent variables
y1 = df_x.loc[:,'CHURN_PREDICTION']
y2 = df_x.loc[:,'CNTCHURN_FLAG']

# prove that the variables were selected correctly
print(X.columns)

# prove that the variables were selected correctly
print(y1.name)
print(y2.name)
# Out:
# Index(['MAINACTBAL', 'DEVICETYPE', 'ISDEVICE3GENABLED', 'VASSUBSCRIBERFLAG',
#        'ISDEVICEDATAENABLED', 'CUSTSEGMENT', 'HANDSETCHANGESFLAGD1_30',
#        'ARPUD1_30', 'SUMVCEREVCD1_30', 'SUMDATAREVCD1_30', 'SUMDATAUSGCD1_30',
#        'SUMVOICEUSGCD1_30', 'SMARTPHONEFLAG', 'CNTZEROBALCD_1',
#        'AGEONNETWORK_group', 'TOTAL_REVENUE', 'DATA_USAGE_IMPACT',
#        'LASTVCEUSGDATE_since', 'LASTRECHRGDATE_since',
#        'LASTREVGENEVTDATE_since'],
#       dtype='object')
# CHURN_PREDICTION
# CNTCHURN_FLAG

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size=0.25, random_state=0, shuffle=True)

# %% [markdown]
# # Trying Multiple Models
# ### Logistic Regression
# ### Random Forest
# ### Gradiente Boosting

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
def create_models(seed=1):
    models = []
    models.append(('logistic_regression', LogisticRegression(random_state=seed)))
    models.append(('random_forest', RandomForestClassifier(random_state=seed)))
    models.append(('gradient_boosting', GradientBoostingClassifier(random_state=seed)))    
    return models
models = create_models()

# %% [markdown]
# ## Testing the result of each model

# %%
from sklearn.metrics import accuracy_score
results = []
names = []
#scoring = 'accuracy'
for name, model in models:
    # fit the model with the training data
    model.fit(X_train, y_train).predict(X_test)
    # make predictions with the testing data
    predictions = model.predict(X_test)
    # calculate accuracy 
    accuracy = accuracy_score(y_test, predictions)
    # append the model name and the accuracy to the lists
    results.append(accuracy)
    names.append(name)
    # print classifier accuracy
    print('Classifier: {}, Accuracy: {})'.format(name, accuracy))
# Out:
# Classifier: logistic_regression, Accuracy: 0.5611)
# Classifier: random_forest, Accuracy: 0.74346)
# Classifier: gradient_boosting, Accuracy: 0.75076)
